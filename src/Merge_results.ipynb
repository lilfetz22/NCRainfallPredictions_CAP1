# %%
import os
import pandas as pd
import numpy as np
import csv
import json
import math

try: 
    __file__
except:
    curr_dir = os.path.abspath('')
else:
    curr_dir = os.path.dirname(os.path.abspath(__file__))
    
app_root = curr_dir if os.path.basename(curr_dir) != "src" else os.path.dirname(curr_dir)

destdir = os.path.join(app_root,'data','manipulated_data')      # non-docker stay in repository


file = os.path.join(destdir,'Exogenous_better_excel.xlsx')
almostcomplete_data = pd.read_excel(file, 'Sheet1', index_col=None)

almostcomplete_data
# Out:
#          Target Location                                 Exogenous Location  \
# 0          Albemarle, NC                                                NaN
# 1                    NaN  CHESTERFIELD 3 E, SC', ' CHERAW, SC', 'PAGELAN...
# 2                    NaN                             'CHESTERFIELD 3 E, SC'
# 3                    NaN                                      ' CHERAW, SC'
# 4                    NaN                             'PAGELAND 9.0 WNW, SC'
# 5                    NaN                               'FORT MILL 4 NW, SC'
# 6                    NaN              'CHESTERFIELD 3 E, SC', ' CHERAW, SC'
# 7                    NaN      CHESTERFIELD 3 E, SC', 'PAGELAND 9.0 WNW, SC'
# 8                    NaN        CHESTERFIELD 3 E, SC', 'FORT MILL 4 NW, SC'
# 9                    NaN                 CHERAW, SC','PAGELAND 9.0 WNW, SC'
# 10                   NaN                ' CHERAW, SC', 'FORT MILL 4 NW, SC'
# 11                   NaN       'PAGELAND 9.0 WNW, SC', 'FORT MILL 4 NW, SC'
# 12                   NaN  'CHESTERFIELD 3 E, SC', ' CHERAW, SC', 'PAGELA...
# 13                   NaN  CHESTERFIELD 3 E, SC', ' CHERAW, SC', 'FORT MI...
# 14                   NaN  CHESTERFIELD 3 E, SC','PAGELAND 9.0 WNW, SC', ...
# 15                   NaN   ' CHERAW, SC', 'PAGELAND 9.0 WNW, SC', 'FORT ...
# 16           Arcola, NC                                                 NaN
# 17                   NaN                  John Kerr Dam, VA', 'Emporia, VA'
# 18                   NaN                                'John Kerr Dam, VA'
# 19                   NaN                                      'Emporia, VA'
# 20        Burlington, NC                                                NaN
# 21                   NaN                    'MARTINSVILLE FILTER PLANT, VA'
# 22           Enfield, NC                                                NaN
# 23                   NaN                 'John Kerr Dam, VA', 'Emporia, VA'
# 24                   NaN                                'John Kerr Dam, VA'
# 25                   NaN                                      'Emporia, VA'
# 26     Greensboro AP, NC                                                NaN
# 27                   NaN       MARTINSVILLE FILTER PLANT, VA', 'STUART, VA'
# 28                   NaN                     MARTINSVILLE FILTER PLANT, VA'
# 29                   NaN                                       'STUART, VA'
# ..                   ...                                                ...
# 382               exmae     ' DARLINGTON, SC', ' DILLON, SC', ' CHERAW, SC'
# 383               exmae   ' DARLINGTON, SC', ' FLORENCE REGIONAL AIRPORT...
# 384               exmae   ' DARLINGTON, SC', ' FLORENCE REGIONAL AIRPORT...
# 385               exmae   ' DARLINGTON, SC', ' FLORENCE REGIONAL AIRPORT...
# 386               exmae   ' DARLINGTON, SC', 'FLORENCE 8 NE, SC', 'CHEST...
# 387               exmae   ' DARLINGTON, SC', 'FLORENCE 8 NE, SC', ' CHER...
# 388               exmae   ' DARLINGTON, SC', 'CHESTERFIELD 3 E, SC', ' C...
# 389               exmae   ' DILLON, SC', ' FLORENCE REGIONAL AIRPORT, SC...
# 390               exmae   ' DILLON, SC', ' FLORENCE REGIONAL AIRPORT, SC...
# 391               exmae   ' DILLON, SC', ' FLORENCE REGIONAL AIRPORT, SC...
# 392               exmae   ' DILLON, SC', 'FLORENCE 8 NE, SC', 'CHESTERFI...
# 393               exmae   ' DILLON, SC', 'FLORENCE 8 NE, SC', ' CHERAW, SC'
# 394               exmae   ' DILLON, SC', 'CHESTERFIELD 3 E, SC', ' CHERA...
# 395               exmae   ' FLORENCE REGIONAL AIRPORT, SC', 'FLORENCE 8 ...
# 396               exmae   ' FLORENCE REGIONAL AIRPORT, SC', 'FLORENCE 8 ...
# 397               exmae   ' FLORENCE REGIONAL AIRPORT, SC', 'CHESTERFIEL...
# 398               exmae   'FLORENCE 8 NE, SC', 'CHESTERFIELD 3 E, SC', '...
# 399               exmae   ' DARLINGTON, SC', ' DILLON, SC', ' FLORENCE R...
# 400               exmae   ' DARLINGTON, SC', ' DILLON, SC', ' FLORENCE R...
# 401               exmae   ' DARLINGTON, SC', ' DILLON, SC', ' FLORENCE R...
# 402               exmae   ' DARLINGTON, SC', ' DILLON, SC', 'FLORENCE 8 ...
# 403               exmae   ' DARLINGTON, SC', ' DILLON, SC', 'FLORENCE 8 ...
# 404       BOONE 1 SE, NC                                                NaN
# 405          DANBURY, NC                                                NaN
# 406             EDEN, NC                                                NaN
# 407   MOUNT AIRY 2 W, NC                                                NaN
# 408  REIDSVILLE 2 NW, NC                                                NaN
# 409  HAYESVILLE 1 NE, NC                                                NaN
# 410      MURPHY 4ESE, NC                                                NaN
# 411             KING, NC                                                NaN
#
#      Mean Absolute Error  Better model
# 0               1.590524           NaN
# 1               2.083258           0.0
# 2               1.942021           0.0
# 3               1.830673           0.0
# 4               2.027484           0.0
# 5               1.788067           0.0
# 6               1.978665           0.0
# 7               2.032507           0.0
# 8               1.981879           0.0
# 9               2.040195           0.0
# 10              1.948375           0.0
# 11              2.042301           0.0
# 12              2.052849           0.0
# 13              1.974485           0.0
# 14              2.043284           0.0
# 15              2.073942           0.0
# 16              1.544256           NaN
# 17              1.838542           0.0
# 18              1.798077           0.0
# 19              1.864039           0.0
# 20              0.788801           NaN
# 21              1.242665           0.0
# 22              0.912939           NaN
# 23              1.318848           0.0
# 24              1.228089           0.0
# 25              1.278897           0.0
# 26              1.620551           NaN
# 27              1.887861           0.0
# 28              1.763337           0.0
# 29              1.687312           0.0
# ..                   ...           ...
# 382             2.125355           NaN
# 383             2.241025           NaN
# 384             2.229659           NaN
# 385             2.346924           NaN
# 386             2.207678           NaN
# 387             2.311281           NaN
# 388             2.289527           NaN
# 389             2.122561           NaN
# 390             2.109478           NaN
# 391             2.208405           NaN
# 392             2.070056           NaN
# 393             2.144010           NaN
# 394             2.149016           NaN
# 395             2.236894           NaN
# 396             2.354114           NaN
# 397             2.362032           NaN
# 398             2.304465           NaN
# 399             2.134537           NaN
# 400             2.077845           NaN
# 401             2.152721           NaN
# 402             2.138086           NaN
# 403             2.131730           NaN
# 404                  NaN           NaN
# 405                  NaN           NaN
# 406                  NaN           NaN
# 407                  NaN           NaN
# 408                  NaN           NaN
# 409                  NaN           NaN
# 410                  NaN           NaN
# 411                  NaN           NaN
#
# [412 rows x 4 columns]

# %%
# Data Massage
# remove exmae text from Target Location column to match predetermined format
import re

almostcomplete_data = almostcomplete_data.drop(['Better model'], axis=1)

unwanted_targetloc_regex = r"^[ ]*exmae[ =]*$"
keymae_regex = r"^keymae of: (.*)$"
exogconv1_regex = r"^[' ]*(.*?)[ ]*[',]*$"
exogconv2_regex = r"',[ ]*'[ ]*"

for key in almostcomplete_data.index:
    value = almostcomplete_data['Target Location'][key]
    if isinstance(value, str) and re.match(unwanted_targetloc_regex, value) is not None:
        almostcomplete_data.at[key, 'Target Location'] = math.nan
    elif isinstance(value, str) and re.match(keymae_regex, value) is not None:
        almostcomplete_data.at[key, 'Target Location'] = re.sub(keymae_regex, r'\1', value).upper().strip(' ')
    elif isinstance(value, str):
        almostcomplete_data.at[key, 'Target Location'] = value.upper().strip(' ')
    
    exogloc_value = almostcomplete_data['Exogenous Location'][key]
    if isinstance(exogloc_value, str):
        exogloc_value2 = re.sub(exogconv1_regex, r'\1', exogloc_value)
        exogloc_value3 = "|".join(re.split(exogconv2_regex, exogloc_value2))
        almostcomplete_data.at[key, 'Exogenous Location'] = exogloc_value3.upper()


# UPPERCASE all Target Locations, and Exogenous Location names
almostcomplete_data.tail(15)
# Out:
#          Target Location                                 Exogenous Location  \
# 397                  NaN  FLORENCE REGIONAL AIRPORT, SC|CHESTERFIELD 3 E...
# 398                  NaN  FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC|CHERAW, SC
# 399                  NaN  DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AI...
# 400                  NaN  DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AI...
# 401                  NaN  DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AI...
# 402                  NaN  DARLINGTON, SC|DILLON, SC|FLORENCE 8 NE, SC|CH...
# 403                  NaN  DARLINGTON, SC|DILLON, SC|FLORENCE 8 NE, SC|CH...
# 404       BOONE 1 SE, NC                                                NaN
# 405          DANBURY, NC                                                NaN
# 406             EDEN, NC                                                NaN
# 407   MOUNT AIRY 2 W, NC                                                NaN
# 408  REIDSVILLE 2 NW, NC                                                NaN
# 409  HAYESVILLE 1 NE, NC                                                NaN
# 410      MURPHY 4ESE, NC                                                NaN
# 411             KING, NC                                                NaN
#
#      Mean Absolute Error
# 397             2.362032
# 398             2.304465
# 399             2.134537
# 400             2.077845
# 401             2.152721
# 402             2.138086
# 403             2.131730
# 404                  NaN
# 405                  NaN
# 406                  NaN
# 407                  NaN
# 408                  NaN
# 409                  NaN
# 410                  NaN
# 411                  NaN

# %%
almostcomplete_dict = {}

for i in almostcomplete_data.index:
    value = almostcomplete_data['Target Location'][i]
    if isinstance(value, str) and not math.isnan(almostcomplete_data['Mean Absolute Error'][i]):
        almostcomplete_dict[value] = { 'keymae': almostcomplete_data['Mean Absolute Error'][i], 'exogen': {} }
        
    elif isinstance(value, str) and math.isnan(almostcomplete_data['Mean Absolute Error'][i]):
        almostcomplete_data.drop(i,axis=0)  # remove unknown keymaes

print(json.dumps(almostcomplete_dict, indent=4))
# Out:
# {
#     "ALBEMARLE, NC": {
#         "keymae": 1.59052394486363,
#         "exogen": {}
#     },
#     "ARCOLA, NC": {
#         "keymae": 1.54425586234438,
#         "exogen": {}
#     },
#     "BURLINGTON, NC": {
#         "keymae": 0.788801134951249,
#         "exogen": {}
#     },
#     "ENFIELD, NC": {
#         "keymae": 0.912938951758521,
#         "exogen": {}
#     },
#     "GREENSBORO AP, NC": {
#         "keymae": 1.62055111053581,
#         "exogen": {}
#     },
#     "HENDERSON 2 NNW, NC": {
#         "keymae": 1.60022457843925,
#         "exogen": {}
#     },
#     "JACKSON SPRINGS 5 WNW, NC": {
#         "keymae": 1.88013588075888,
#         "exogen": {}
#     },
#     "LAURINBURG, NC": {
#         "keymae": 1.64842225744649,
#         "exogen": {}
#     },
#     "ROANOKE RAPIDS, NC": {
#         "keymae": 1.97334050874123,
#         "exogen": {}
#     },
#     "MURFREESBORO, NC": {
#         "keymae": 1.71910997032104,
#         "exogen": {}
#     },
#     "LUMBERTON AREA, NC": {
#         "keymae": 1.69981932215264,
#         "exogen": {}
#     },
#     "LONGWOOD, NC": {
#         "keymae": 2.23595682595916,
#         "exogen": {}
#     },
#     "WHITEVILLE 7 NW, NC": {
#         "keymae": 2.16511695179729,
#         "exogen": {}
#     },
#     "CHARLOTTE AREA, NC": {
#         "keymae": 1.68273971746638,
#         "exogen": {}
#     },
#     "MOUNT MITCHELL AREA, NC": {
#         "keymae": 3.30980488230583,
#         "exogen": {}
#     },
#     "ASHEVILLE AIRPORT, NC": {
#         "keymae": 2.09373067533011,
#         "exogen": {}
#     },
#     "BANNER ELK, NC": {
#         "keymae": 2.05316404955102,
#         "exogen": {}
#     },
#     "BEECH MOUNTAIN, NC": {
#         "keymae": 2.19424255142705,
#         "exogen": {}
#     },
#     "BRYSON CITY 4, NC": {
#         "keymae": 2.02307985014958,
#         "exogen": {}
#     },
#     "BREVARD, NC": {
#         "keymae": 3.17583831704875,
#         "exogen": {}
#     },
#     "CASAR, NC": {
#         "keymae": 1.9931330926726,
#         "exogen": {}
#     },
#     "COWEETA EXP STATION, NC": {
#         "keymae": 2.50449023648598,
#         "exogen": {}
#     },
#     "CULLOWHEE, NC": {
#         "keymae": 1.79707642572302,
#         "exogen": {}
#     },
#     "FOREST CITY 8 W, NC": {
#         "keymae": 1.86483286971242,
#         "exogen": {}
#     },
#     "FRANKLIN, NC": {
#         "keymae": 1.91226192479846,
#         "exogen": {}
#     },
#     "GASTONIA, NC": {
#         "keymae": 1.61230615384118,
#         "exogen": {}
#     },
#     "GRANDFATHER MTN, NC": {
#         "keymae": 2.58806403787115,
#         "exogen": {}
#     },
#     "HENDERSONVILLE 1 NE, NC": {
#         "keymae": 2.46558658863095,
#         "exogen": {}
#     },
#     "HIGHLANDS, NC": {
#         "keymae": 3.34329767242193,
#         "exogen": {}
#     },
#     "HOT SPRINGS, NC": {
#         "keymae": 1.5646538909139,
#         "exogen": {}
#     },
#     "LAKE LURE 2, NC": {
#         "keymae": 2.2406539900917,
#         "exogen": {}
#     },
#     "LAKE TOXAWAY 2 SW, NC": {
#         "keymae": 3.67607983397718,
#         "exogen": {}
#     },
#     "MOUNT HOLLY 4 NE, NC": {
#         "keymae": 1.63478493204316,
#         "exogen": {}
#     },
#     "TAPOCO, NC": {
#         "keymae": 0.980067356613127,
#         "exogen": {}
#     },
#     "TRYON, NC": {
#         "keymae": 2.6823507498407,
#         "exogen": {}
#     },
#     "WAYNESVILLE 1 E, NC": {
#         "keymae": 1.74748213942306,
#         "exogen": {}
#     }
# }

# %%
# Collect exmae values and insert into dictionary nested under the associated keymae

dict_keys = list(almostcomplete_dict.keys())
current_dict_index = -1
collecting = False

i = 0
while i < len(almostcomplete_data.index):
    exogloc = almostcomplete_data['Exogenous Location'][i]
    if isinstance(exogloc, str) and collecting:
#         print("collecting... almostcomplete_dict[dict_keys[{0}]]['exogen'][{1}]".format(current_dict_index, exogloc))
        key = dict_keys[current_dict_index]
        almostcomplete_dict[key]['exogen'][exogloc] = { 'exmae': almostcomplete_data['Mean Absolute Error'][i] }
    elif isinstance(exogloc, str) and not collecting:
        found_keymae = almostcomplete_data['Target Location'][i-1]
        if found_keymae in dict_keys:
            current_dict_index = dict_keys.index(found_keymae)
            collecting = True
            i -= 1
        else:
            print("ERROR: Found exogloc ({0}) does not exist in almostcomplete_dict".format(exogloc))
    else:
        collecting = False
        
    i += 1

print(json.dumps(almostcomplete_dict, indent=4))
# with open(os.path.join(destdir, "almostThere.json"), "w") as almost_there_file:
#     almost_there_file.write( json.dumps(almostcomplete_dict, indent=4) )
# Out:
# {
#     "ALBEMARLE, NC": {
#         "keymae": 1.59052394486363,
#         "exogen": {
#             "CHESTERFIELD 3 E, SC|CHERAW, SC|PAGELAND 9.0 WNW, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 2.08325758240936
#             },
#             "CHESTERFIELD 3 E, SC": {
#                 "exmae": 1.94202068068645
#             },
#             "CHERAW, SC": {
#                 "exmae": 1.83067341056705
#             },
#             "PAGELAND 9.0 WNW, SC": {
#                 "exmae": 2.0274841948442
#             },
#             "FORT MILL 4 NW, SC": {
#                 "exmae": 1.78806744315493
#             },
#             "CHESTERFIELD 3 E, SC|CHERAW, SC": {
#                 "exmae": 1.97866499847341
#             },
#             "CHESTERFIELD 3 E, SC|PAGELAND 9.0 WNW, SC": {
#                 "exmae": 2.03250744234255
#             },
#             "CHESTERFIELD 3 E, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 1.98187923521911
#             },
#             "CHERAW, SC|PAGELAND 9.0 WNW, SC": {
#                 "exmae": 2.04019548152603
#             },
#             "CHERAW, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 1.94837496418439
#             },
#             "PAGELAND 9.0 WNW, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 2.04230102033306
#             },
#             "CHESTERFIELD 3 E, SC|CHERAW, SC|PAGELAND 9.0 WNW, SC": {
#                 "exmae": 2.0528494078611
#             },
#             "CHESTERFIELD 3 E, SC|CHERAW, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 1.97448509349147
#             },
#             "CHESTERFIELD 3 E, SC|PAGELAND 9.0 WNW, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 2.04328392919432
#             },
#             "CHERAW, SC|PAGELAND 9.0 WNW, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 2.07394246531023
#             }
#         }
#     },
#     "ARCOLA, NC": {
#         "keymae": 1.54425586234438,
#         "exogen": {
#             "JOHN KERR DAM, VA|EMPORIA, VA": {
#                 "exmae": 1.83854245049347
#             },
#             "JOHN KERR DAM, VA": {
#                 "exmae": 1.7980768982623
#             },
#             "EMPORIA, VA": {
#                 "exmae": 1.86403881340135
#             }
#         }
#     },
#     "BURLINGTON, NC": {
#         "keymae": 0.788801134951249,
#         "exogen": {
#             "MARTINSVILLE FILTER PLANT, VA": {
#                 "exmae": 1.24266460696556
#             }
#         }
#     },
#     "ENFIELD, NC": {
#         "keymae": 0.912938951758521,
#         "exogen": {
#             "JOHN KERR DAM, VA|EMPORIA, VA": {
#                 "exmae": 1.31884798934265
#             },
#             "JOHN KERR DAM, VA": {
#                 "exmae": 1.22808940925125
#             },
#             "EMPORIA, VA": {
#                 "exmae": 1.27889667774621
#             }
#         }
#     },
#     "GREENSBORO AP, NC": {
#         "keymae": 1.62055111053581,
#         "exogen": {
#             "MARTINSVILLE FILTER PLANT, VA|STUART, VA": {
#                 "exmae": 1.88786062008521
#             },
#             "MARTINSVILLE FILTER PLANT, VA": {
#                 "exmae": 1.76333713411939
#             },
#             "STUART, VA": {
#                 "exmae": 1.68731174391954
#             }
#         }
#     },
#     "HENDERSON 2 NNW, NC": {
#         "keymae": 1.60022457843925,
#         "exogen": {
#             "SOUTH BOSTON, VA|JOHN KERR DAM, VA": {
#                 "exmae": 1.94367846959537
#             },
#             "SOUTH BOSTON, VA": {
#                 "exmae": 1.90509146450438
#             },
#             "JOHN KERR DAM, VA": {
#                 "exmae": 1.90667075553528
#             }
#         }
#     },
#     "JACKSON SPRINGS 5 WNW, NC": {
#         "keymae": 1.88013588075888,
#         "exogen": {
#             "CHESTERFIELD 3 E, SC|CHERAW, SC": {
#                 "exmae": 2.27692897709342
#             },
#             "CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.68565757574308
#             },
#             "CHERAW, SC": {
#                 "exmae": 2.16768574858637
#             }
#         }
#     },
#     "LAURINBURG, NC": {
#         "keymae": 1.64842225744649,
#         "exogen": {
#             "DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC|CHERAW, SC": {
#                 "exmae": 2.17553847597348
#             },
#             "DARLINGTON, SC": {
#                 "exmae": 2.04804548743379
#             },
#             "DILLON, SC": {
#                 "exmae": 1.85625426318498
#             },
#             "FLORENCE REGIONAL AIRPORT, SC": {
#                 "exmae": 2.26858689711078
#             },
#             "FLORENCE 8 NE, SC": {
#                 "exmae": 2.07915280832709
#             },
#             "CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.25608299608892
#             },
#             "CHERAW, SC": {
#                 "exmae": 2.2657683522657
#             },
#             "DARLINGTON, SC|DILLON, SC": {
#                 "exmae": 2.00426362695676
#             },
#             "DARLINGTON, SC|FLORENCE REGIONAL AIRPORT, SC": {
#                 "exmae": 2.22768278671585
#             },
#             "DARLINGTON, SC|FLORENCE 8 NE, SC": {
#                 "exmae": 2.15208210049137
#             },
#             "DARLINGTON, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.15211242258636
#             },
#             "DARLINGTON, SC|CHERAW, SC": {
#                 "exmae": 2.28492109713038
#             },
#             "DILLON, SC|FLORENCE REGIONAL AIRPORT, SC": {
#                 "exmae": 2.13401689435676
#             },
#             "DILLON, SC|FLORENCE 8 NE, SC": {
#                 "exmae": 1.9336379439479
#             },
#             "DILLON, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.038079758613
#             },
#             "DILLON, SC|CHERAW, SC": {
#                 "exmae": 2.13754733306288
#             },
#             "FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC": {
#                 "exmae": 2.18873870271043
#             },
#             "FLORENCE REGIONAL AIRPORT, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.29657486328574
#             },
#             "FLORENCE REGIONAL AIRPORT, SC|CHERAW, SC": {
#                 "exmae": 2.43736132068584
#             },
#             "FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.12248887706251
#             },
#             "FLORENCE 8 NE, SC|CHERAW, SC": {
#                 "exmae": 2.30635295753451
#             },
#             "CHESTERFIELD 3 E, SC|CHERAW, SC": {
#                 "exmae": 2.31446218296315
#             },
#             "DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AIRPORT, SC": {
#                 "exmae": 2.12255563998553
#             },
#             "DARLINGTON, SC|DILLON, SC|FLORENCE 8 NE, SC": {
#                 "exmae": 2.02315109659763
#             },
#             "DARLINGTON, SC|DILLON, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.15308766027401
#             },
#             "DARLINGTON, SC|DILLON, SC|CHERAW, SC": {
#                 "exmae": 2.12535543720441
#             },
#             "DARLINGTON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC": {
#                 "exmae": 2.24102457751095
#             },
#             "DARLINGTON, SC|FLORENCE REGIONAL AIRPORT, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.22965948953402
#             },
#             "DARLINGTON, SC|FLORENCE REGIONAL AIRPORT, SC|CHERAW, SC": {
#                 "exmae": 2.34692426325807
#             },
#             "DARLINGTON, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.20767836871335
#             },
#             "DARLINGTON, SC|FLORENCE 8 NE, SC|CHERAW, SC": {
#                 "exmae": 2.31128051657491
#             },
#             "DARLINGTON, SC|CHESTERFIELD 3 E, SC|CHERAW, SC": {
#                 "exmae": 2.28952741077562
#             },
#             "DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC": {
#                 "exmae": 2.12256079233491
#             },
#             "DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.10947841279159
#             },
#             "DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|CHERAW, SC": {
#                 "exmae": 2.20840493204414
#             },
#             "DILLON, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.07005606073679
#             },
#             "DILLON, SC|FLORENCE 8 NE, SC|CHERAW, SC": {
#                 "exmae": 2.14400992086905
#             },
#             "DILLON, SC|CHESTERFIELD 3 E, SC|CHERAW, SC": {
#                 "exmae": 2.14901644508763
#             },
#             "FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.23689395337484
#             },
#             "FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHERAW, SC": {
#                 "exmae": 2.3541137484821
#             },
#             "FLORENCE REGIONAL AIRPORT, SC|CHESTERFIELD 3 E, SC|CHERAW, SC": {
#                 "exmae": 2.36203240173483
#             },
#             "FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC|CHERAW, SC": {
#                 "exmae": 2.30446526463454
#             },
#             "DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC": {
#                 "exmae": 2.1345371745788
#             },
#             "DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.07784528815509
#             },
#             "DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|CHERAW, SC": {
#                 "exmae": 2.15272106535951
#             },
#             "DARLINGTON, SC|DILLON, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC": {
#                 "exmae": 2.13808639195219
#             },
#             "DARLINGTON, SC|DILLON, SC|FLORENCE 8 NE, SC|CHERAW, SC": {
#                 "exmae": 2.13172979181575
#             }
#         }
#     },
#     "ROANOKE RAPIDS, NC": {
#         "keymae": 1.97334050874123,
#         "exogen": {
#             "EMPORIA, VA": {
#                 "exmae": 2.40367796786913
#             }
#         }
#     },
#     "MURFREESBORO, NC": {
#         "keymae": 1.71910997032104,
#         "exogen": {
#             "EMPORIA, VA": {
#                 "exmae": 2.0084479745912
#             }
#         }
#     },
#     "LUMBERTON AREA, NC": {
#         "keymae": 1.69981932215264,
#         "exogen": {
#             "DILLON, SC": {
#                 "exmae": 1.88612326248235
#             }
#         }
#     },
#     "LONGWOOD, NC": {
#         "keymae": 2.23595682595916,
#         "exogen": {
#             "LORIS 2 S, SC|MYRTLE BEACH AREA, SC": {
#                 "exmae": 2.61173336999646
#             },
#             "LORIS 2 S, SC": {
#                 "exmae": 2.32508704962889
#             },
#             "MYRTLE BEACH AREA, SC": {
#                 "exmae": 2.74269297251696
#             }
#         }
#     },
#     "WHITEVILLE 7 NW, NC": {
#         "keymae": 2.16511695179729,
#         "exogen": {
#             "LORIS 2 S, SC": {
#                 "exmae": 2.15318610926817
#             }
#         }
#     },
#     "CHARLOTTE AREA, NC": {
#         "keymae": 1.68273971746638,
#         "exogen": {
#             "CATAWBA, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 1.85494110448607
#             },
#             "CATAWBA, SC": {
#                 "exmae": 1.82337078934904
#             },
#             "FORT MILL 4 NW, SC": {
#                 "exmae": 1.84723637145798
#             }
#         }
#     },
#     "MOUNT MITCHELL AREA, NC": {
#         "keymae": 3.30980488230583,
#         "exogen": {
#             "ERWIN 1 W, TN": {
#                 "exmae": 3.55453763092407
#             }
#         }
#     },
#     "ASHEVILLE AIRPORT, NC": {
#         "keymae": 2.09373067533011,
#         "exogen": {
#             "CAESARS HEAD, SC|CLEVELAND 3S, SC": {
#                 "exmae": 2.43467343823909
#             },
#             "CAESARS HEAD, SC": {
#                 "exmae": 2.56316449326825
#             },
#             "CLEVELAND 3S, SC": {
#                 "exmae": 2.47896220520937
#             }
#         }
#     },
#     "BANNER ELK, NC": {
#         "keymae": 2.05316404955102,
#         "exogen": {
#             "ELIZABETHTON, TN|ERWIN 1 W, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.51826972721789
#             },
#             "ELIZABETHTON, TN": {
#                 "exmae": 2.25234719383168
#             },
#             "ERWIN 1 W, TN": {
#                 "exmae": 2.33351265887378
#             },
#             "ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.56192192815938
#             },
#             "ELIZABETHTON, TN|ERWIN 1 W, TN": {
#                 "exmae": 2.30876631475562
#             },
#             "ELIZABETHTON, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.49929404572916
#             },
#             "ERWIN 1 W, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.50109470939746
#             }
#         }
#     },
#     "BEECH MOUNTAIN, NC": {
#         "keymae": 2.19424255142705,
#         "exogen": {
#             "BRISTOL AP, TN|ELIZABETHTON, TN|ERWIN 1 W, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.52824069446962
#             },
#             "BRISTOL AP, TN": {
#                 "exmae": 2.33954325905736
#             },
#             "ELIZABETHTON, TN": {
#                 "exmae": 2.24770062094778
#             },
#             "ERWIN 1 W, TN": {
#                 "exmae": 2.33760424797326
#             },
#             "ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.54378358381963
#             },
#             "BRISTOL AP, TN|ELIZABETHTON, TN": {
#                 "exmae": 2.30648178773941
#             },
#             "BRISTOL AP, TN|ERWIN 1 W, TN": {
#                 "exmae": 2.36116132603327
#             },
#             "BRISTOL AP, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.5049180927296
#             },
#             "ELIZABETHTON, TN|ERWIN 1 W, TN": {
#                 "exmae": 2.33039213223746
#             },
#             "ELIZABETHTON, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.49092201239243
#             },
#             "ERWIN 1 W, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.49674501129869
#             },
#             "BRISTOL AP, TN|ELIZABETHTON, TN|ERWIN 1 W, TN": {
#                 "exmae": 2.36104605097083
#             },
#             "BRISTOL AP, TN|ELIZABETHTON, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.47719883041615
#             },
#             "BRISTOL AP, TN|ERWIN 1 W, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.53218136548665
#             },
#             "ELIZABETHTON, TN|ERWIN 1 W, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.45364578169454
#             }
#         }
#     },
#     "BRYSON CITY 4, NC": {
#         "keymae": 2.02307985014958,
#         "exogen": {
#             "GATLINBURG 2 SW, TN|MT LECONTE, TN|NEWFOUND GAP, TN|TOWNSEND 5S, TN": {
#                 "exmae": 2.35565894105662
#             },
#             "GATLINBURG 2 SW, TN": {
#                 "exmae": 2.16371685806433
#             },
#             "MT LECONTE, TN": {
#                 "exmae": 2.35911800119529
#             },
#             "NEWFOUND GAP, TN": {
#                 "exmae": 2.34662000491503
#             },
#             "TOWNSEND 5S, TN": {
#                 "exmae": 2.30116994875194
#             },
#             "GATLINBURG 2 SW, TN|MT LECONTE, TN": {
#                 "exmae": 2.63262331971403
#             },
#             "GATLINBURG 2 SW, TN|NEWFOUND GAP, TN": {
#                 "exmae": 2.27755036666671
#             },
#             "GATLINBURG 2 SW, TN|TOWNSEND 5S, TN": {
#                 "exmae": 2.27882292526878
#             },
#             "MT LECONTE, TN|NEWFOUND GAP, TN": {
#                 "exmae": 2.36281547819088
#             },
#             "MT LECONTE, TN|TOWNSEND 5S, TN": {
#                 "exmae": 2.43220273272366
#             },
#             "NEWFOUND GAP, TN|TOWNSEND 5S, TN": {
#                 "exmae": 2.34845164378141
#             },
#             "GATLINBURG 2 SW, TN|MT LECONTE, TN|NEWFOUND GAP, TN": {
#                 "exmae": 2.34731080230987
#             },
#             "GATLINBURG 2 SW, TN|MT LECONTE, TN|TOWNSEND 5S, TN": {
#                 "exmae": 2.3867342007068
#             },
#             "GATLINBURG 2 SW, TN|NEWFOUND GAP, TN|TOWNSEND 5S, TN": {
#                 "exmae": 2.31455750421014
#             },
#             "MT LECONTE, TN|NEWFOUND GAP, TN|TOWNSEND 5S, TN": {
#                 "exmae": 2.36358955844773
#             }
#         }
#     },
#     "BREVARD, NC": {
#         "keymae": 3.17583831704875,
#         "exogen": {
#             "PICKENS AREA, SC|CAESARS HEAD, SC|CLEVELAND 3S, SC": {
#                 "exmae": 3.42760406452745
#             },
#             "PICKENS AREA, SC": {
#                 "exmae": 3.2331685569617
#             },
#             "CAESARS HEAD, SC": {
#                 "exmae": 3.41255543907734
#             },
#             "CLEVELAND 3S, SC": {
#                 "exmae": 3.40880670290347
#             },
#             "PICKENS AREA, SC|CAESARS HEAD, SC": {
#                 "exmae": 3.34075668311912
#             },
#             "PICKENS AREA, SC|CLEVELAND 3S, SC": {
#                 "exmae": 3.32831205087609
#             },
#             "CAESARS HEAD, SC|CLEVELAND 3S, SC": {
#                 "exmae": 3.45959946372926
#             }
#         }
#     },
#     "CASAR, NC": {
#         "keymae": 1.9931330926726,
#         "exogen": {
#             "CHESNEE 7 WSW, SC|GAFFNEY 6 E, SC": {
#                 "exmae": 1.91044660427743
#             },
#             "CHESNEE 7 WSW, SC": {
#                 "exmae": 1.9664932880645
#             },
#             "GAFFNEY 6 E, SC": {
#                 "exmae": 1.8382562244764
#             }
#         }
#     },
#     "COWEETA EXP STATION, NC": {
#         "keymae": 2.50449023648598,
#         "exogen": {
#             "LONG CREEK, SC|WALHALLA, SC|CLAYTON 1 SSW, GA|HELEN, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.23068531459928
#             },
#             "LONG CREEK, SC": {
#                 "exmae": 2.68699338453716
#             },
#             "WALHALLA, SC": {
#                 "exmae": 3.11692008910286
#             },
#             "CLAYTON 1 SSW, GA": {
#                 "exmae": 2.98025173985434
#             },
#             "HELEN, GA": {
#                 "exmae": 3.22116794242295
#             },
#             "SAUTEE 3W, GA": {
#                 "exmae": 3.36194562477167
#             },
#             "LONG CREEK, SC|WALHALLA, SC": {
#                 "exmae": 3.11863892909903
#             },
#             "LONG CREEK, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 3.15617686082936
#             },
#             "LONG CREEK, SC|HELEN, GA": {
#                 "exmae": 3.23990324071421
#             },
#             "LONG CREEK, SC|SAUTEE 3W, GA": {
#                 "exmae": 3.33949157927608
#             },
#             "WALHALLA, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 3.11645336135315
#             },
#             "WALHALLA, SC|HELEN, GA": {
#                 "exmae": 3.28391573201725
#             },
#             "WALHALLA, SC|SAUTEE 3W, GA": {
#                 "exmae": 3.32147999392229
#             },
#             "CLAYTON 1 SSW, GA|HELEN, GA": {
#                 "exmae": 3.1973954336547
#             },
#             "CLAYTON 1 SSW, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.25521667466779
#             },
#             "HELEN, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.35447961173581
#             },
#             "LONG CREEK, SC|WALHALLA, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 3.13150195399586
#             },
#             "LONG CREEK, SC|WALHALLA, SC|HELEN, GA": {
#                 "exmae": 3.25276556839087
#             },
#             "LONG CREEK, SC|WALHALLA, SC|SAUTEE 3W, GA": {
#                 "exmae": 3.31777083123004
#             },
#             "LONG CREEK, SC|CLAYTON 1 SSW, GA|HELEN, GA": {
#                 "exmae": 3.18569563644492
#             },
#             "LONG CREEK, SC|CLAYTON 1 SSW, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.26116926640567
#             },
#             "LONG CREEK, SC|HELEN, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.33638493156137
#             },
#             "WALHALLA, SC|CLAYTON 1 SSW, GA|HELEN, GA": {
#                 "exmae": 3.21111827258244
#             },
#             "WALHALLA, SC|CLAYTON 1 SSW, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.22639006605467
#             },
#             "WALHALLA, SC|HELEN, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.44185429544234
#             },
#             "CLAYTON 1 SSW, GA|HELEN, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.24692147441807
#             },
#             "LONG CREEK, SC|WALHALLA, SC|CLAYTON 1 SSW, GA|HELEN, GA": {
#                 "exmae": 3.20174318441332
#             },
#             "LONG CREEK, SC|WALHALLA, SC|CLAYTON 1 SSW, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.2345771064472
#             },
#             "LONG CREEK, SC|WALHALLA, SC|HELEN, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.33692651407984
#             },
#             "LONG CREEK, SC|CLAYTON 1 SSW, GA|HELEN, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.2517445440228
#             },
#             "WALHALLA, SC|CLAYTON 1 SSW, GA|HELEN, GA|SAUTEE 3W, GA": {
#                 "exmae": 3.22145117338574
#             }
#         }
#     },
#     "CULLOWHEE, NC": {
#         "keymae": 1.79707642572302,
#         "exogen": {
#             "MT LECONTE, TN|NEWFOUND GAP, TN": {
#                 "exmae": 2.35951160612129
#             },
#             "MT LECONTE, TN": {
#                 "exmae": 2.26012766789672
#             },
#             "NEWFOUND GAP, TN": {
#                 "exmae": 2.2895789588378
#             }
#         }
#     },
#     "FOREST CITY 8 W, NC": {
#         "keymae": 1.86483286971242,
#         "exogen": {
#             "CHESNEE 7 WSW, SC|GAFFNEY 6 E, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 1.92888317489229
#             },
#             "CHESNEE 7 WSW, SC": {
#                 "exmae": 1.93499690504583
#             },
#             "GAFFNEY 6 E, SC": {
#                 "exmae": 1.7541216788822
#             },
#             "SPARTANBURG 3 SSE, SC": {
#                 "exmae": 1.9134830193208
#             },
#             "CHESNEE 7 WSW, SC|GAFFNEY 6 E, SC": {
#                 "exmae": 1.88068435036084
#             },
#             "CHESNEE 7 WSW, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 1.94353622860597
#             },
#             "GAFFNEY 6 E, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 1.83721710012003
#             }
#         }
#     },
#     "FRANKLIN, NC": {
#         "keymae": 1.91226192479846,
#         "exogen": {
#             "LONG CREEK, SC|CLAYTON 1 SSW, GA|NEWFOUND GAP, TN": {
#                 "exmae": 2.07740437429297
#             },
#             "LONG CREEK, SC": {
#                 "exmae": 2.04243334399589
#             },
#             "CLAYTON 1 SSW, GA": {
#                 "exmae": 1.93506476404939
#             },
#             "NEWFOUND GAP, TN": {
#                 "exmae": 2.11637286408869
#             },
#             "LONG CREEK, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 1.9928230928366
#             },
#             "LONG CREEK, SC|NEWFOUND GAP, TN": {
#                 "exmae": 2.12012652613177
#             },
#             "CLAYTON 1 SSW, GA|NEWFOUND GAP, TN": {
#                 "exmae": 2.06311538352246
#             }
#         }
#     },
#     "GASTONIA, NC": {
#         "keymae": 1.61230615384118,
#         "exogen": {
#             "FORT MILL 4 NW, SC|GAFFNEY 6 E, SC": {
#                 "exmae": 1.60508507545129
#             },
#             "FORT MILL 4 NW, SC": {
#                 "exmae": 1.65617407719515
#             },
#             "GAFFNEY 6 E, SC": {
#                 "exmae": 1.6099578514009
#             }
#         }
#     },
#     "GRANDFATHER MTN, NC": {
#         "keymae": 2.58806403787115,
#         "exogen": {
#             "ELIZABETHTON, TN|ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.97106152453339
#             },
#             "ELIZABETHTON, TN": {
#                 "exmae": 2.69524767468778
#             },
#             "ROAN MOUNTAIN 3SW, TN": {
#                 "exmae": 2.97845074957975
#             }
#         }
#     },
#     "HENDERSONVILLE 1 NE, NC": {
#         "keymae": 2.46558658863095,
#         "exogen": {
#             "CAESARS HEAD, SC|CLEVELAND 3S, SC": {
#                 "exmae": 2.8025108020851
#             },
#             "CAESARS HEAD, SC": {
#                 "exmae": 2.74042261814884
#             },
#             "CLEVELAND 3S, SC": {
#                 "exmae": 2.69553022302382
#             }
#         }
#     },
#     "HIGHLANDS, NC": {
#         "keymae": 3.34329767242193,
#         "exogen": {
#             "PICKENS AREA, SC|LONG CREEK, SC|WALHALLA, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 3.99797080982787
#             },
#             "PICKENS AREA, SC": {
#                 "exmae": 3.68379400382927
#             },
#             "LONG CREEK, SC": {
#                 "exmae": 3.78121361365782
#             },
#             "WALHALLA, SC": {
#                 "exmae": 3.94847387822863
#             },
#             "CLAYTON 1 SSW, GA": {
#                 "exmae": 3.92690773134028
#             },
#             "PICKENS AREA, SC|LONG CREEK, SC": {
#                 "exmae": 3.86143682150895
#             },
#             "PICKENS AREA, SC|WALHALLA, SC": {
#                 "exmae": 3.93584948093295
#             },
#             "PICKENS AREA, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 3.97947259918005
#             },
#             "LONG CREEK, SC|WALHALLA, SC": {
#                 "exmae": 4.05054860839878
#             },
#             "LONG CREEK, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 4.02790198327683
#             },
#             "WALHALLA, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 4.09037143016409
#             },
#             "PICKENS AREA, SC|LONG CREEK, SC|WALHALLA, SC": {
#                 "exmae": 3.99308504206754
#             },
#             "PICKENS AREA, SC|LONG CREEK, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 3.97490346819251
#             },
#             "PICKENS AREA, SC|WALHALLA, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 4.05795256823002
#             },
#             "LONG CREEK, SC|WALHALLA, SC|CLAYTON 1 SSW, GA": {
#                 "exmae": 4.05041271320268
#             }
#         }
#     },
#     "HOT SPRINGS, NC": {
#         "keymae": 1.5646538909139,
#         "exogen": {
#             "ERWIN 1 W, TN|GREENEVILLE EXP STA, TN|NEWPORT 1 NW, TN": {
#                 "exmae": 1.77831641167892
#             },
#             "ERWIN 1 W, TN": {
#                 "exmae": 1.95220475328367
#             },
#             "GREENEVILLE EXP STA, TN": {
#                 "exmae": 2.7033183330983
#             },
#             "NEWPORT 1 NW, TN": {
#                 "exmae": 1.70856939190188
#             },
#             "ERWIN 1 W, TN|GREENEVILLE EXP STA, TN": {
#                 "exmae": 1.82881375794553
#             },
#             "ERWIN 1 W, TN|NEWPORT 1 NW, TN": {
#                 "exmae": 1.77681356056498
#             },
#             "GREENEVILLE EXP STA, TN|NEWPORT 1 NW, TN": {
#                 "exmae": 1.72458205546583
#             }
#         }
#     },
#     "LAKE LURE 2, NC": {
#         "keymae": 2.2406539900917,
#         "exogen": {
#             "CHESNEE 7 WSW, SC|CLEVELAND 3S, SC": {
#                 "exmae": 2.40607385594172
#             },
#             "CHESNEE 7 WSW, SC": {
#                 "exmae": 2.21126990164505
#             },
#             "CLEVELAND 3S, SC": {
#                 "exmae": 2.47619458277572
#             }
#         }
#     },
#     "LAKE TOXAWAY 2 SW, NC": {
#         "keymae": 3.67607983397718,
#         "exogen": {
#             "PICKENS AREA, SC|CAESARS HEAD, SC|CLEVELAND 3S, SC|LONG CREEK, SC|WALHALLA, SC": {
#                 "exmae": 4.19372930563993
#             },
#             "PICKENS AREA, SC": {
#                 "exmae": 3.88299743397298
#             },
#             "CAESARS HEAD, SC": {
#                 "exmae": 4.10598617467573
#             },
#             "CLEVELAND 3S, SC": {
#                 "exmae": 3.89377100383897
#             },
#             "LONG CREEK, SC": {
#                 "exmae": 3.79328073519517
#             },
#             "WALHALLA, SC": {
#                 "exmae": 4.0056500219152
#             },
#             "PICKENS AREA, SC|CAESARS HEAD, SC": {
#                 "exmae": 4.0799654223688
#             },
#             "PICKENS AREA, SC|CLEVELAND 3S, SC": {
#                 "exmae": 3.83523114820618
#             },
#             "PICKENS AREA, SC|LONG CREEK, SC": {
#                 "exmae": 4.09481614260339
#             },
#             "PICKENS AREA, SC|WALHALLA, SC": {
#                 "exmae": 4.02927963284457
#             },
#             "CAESARS HEAD, SC|CLEVELAND 3S, SC": {
#                 "exmae": 4.04246178300365
#             },
#             "CAESARS HEAD, SC|LONG CREEK, SC": {
#                 "exmae": 4.09975602645439
#             },
#             "CAESARS HEAD, SC|WALHALLA, SC": {
#                 "exmae": 4.18914436388675
#             },
#             "CLEVELAND 3S, SC|LONG CREEK, SC": {
#                 "exmae": 4.0131115061629
#             },
#             "CLEVELAND 3S, SC|WALHALLA, SC": {
#                 "exmae": 4.01585756733338
#             }
#         }
#     },
#     "MOUNT HOLLY 4 NE, NC": {
#         "keymae": 1.63478493204316,
#         "exogen": {
#             "CATAWBA, SC|CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC|LOCKHART, SC": {
#                 "exmae": 1.64346441375155
#             },
#             "CATAWBA, SC": {
#                 "exmae": 1.68816660688149
#             },
#             "CHESNEE 7 WSW, SC": {
#                 "exmae": 1.57341144579111
#             },
#             "CHESTER 1 SE, SC": {
#                 "exmae": 1.61138254726406
#             },
#             "FORT MILL 4 NW, SC": {
#                 "exmae": 1.71894646725883
#             },
#             "GAFFNEY 6 E, SC": {
#                 "exmae": 1.63312534055945
#             },
#             "LOCKHART, SC": {
#                 "exmae": 1.61338199887875
#             },
#             "CATAWBA, SC|CHESNEE 7 WSW, SC": {
#                 "exmae": 1.64979267480182
#             },
#             "CATAWBA, SC|CHESTER 1 SE, SC": {
#                 "exmae": 1.65930320795771
#             },
#             "CATAWBA, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 1.71992748119536
#             },
#             "CATAWBA, SC|GAFFNEY 6 E, SC": {
#                 "exmae": 1.59679867563464
#             },
#             "CATAWBA, SC|LOCKHART, SC": {
#                 "exmae": 1.64617514511116
#             },
#             "CHESNEE 7 WSW, SC|CHESTER 1 SE, SC": {
#                 "exmae": 1.59330635914878
#             },
#             "CHESNEE 7 WSW, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 1.68680684677131
#             },
#             "CHESNEE 7 WSW, SC|GAFFNEY 6 E, SC": {
#                 "exmae": 1.52970862870064
#             },
#             "CHESNEE 7 WSW, SC|LOCKHART, SC": {
#                 "exmae": 1.5978320489258
#             },
#             "CHESTER 1 SE, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 1.69383647477668
#             },
#             "CHESTER 1 SE, SC|GAFFNEY 6 E, SC": {
#                 "exmae": 1.58178931080188
#             },
#             "CHESTER 1 SE, SC|LOCKHART, SC": {
#                 "exmae": 1.60438459386221
#             },
#             "FORT MILL 4 NW, SC|GAFFNEY 6 E, SC": {
#                 "exmae": 1.62231188870168
#             },
#             "FORT MILL 4 NW, SC|LOCKHART, SC": {
#                 "exmae": 1.67761240416753
#             },
#             "GAFFNEY 6 E, SC|LOCKHART, SC": {
#                 "exmae": 1.58643919403826
#             },
#             "CATAWBA, SC|CHESNEE 7 WSW, SC|CHESTER 1 SE, SC": {
#                 "exmae": 1.62153179917427
#             },
#             "CATAWBA, SC|CHESNEE 7 WSW, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 1.69892960839564
#             },
#             "CATAWBA, SC|CHESNEE 7 WSW, SC|GAFFNEY 6 E, SC": {
#                 "exmae": 1.57066584748015
#             },
#             "CATAWBA, SC|CHESNEE 7 WSW, SC|LOCKHART, SC": {
#                 "exmae": 1.62786132957747
#             },
#             "CATAWBA, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC": {
#                 "exmae": 1.70457441256051
#             },
#             "CATAWBA, SC|CHESTER 1 SE, SC|GAFFNEY 6 E, SC": {
#                 "exmae": 1.58283009851941
#             },
#             "CATAWBA, SC|CHESTER 1 SE, SC|LOCKHART, SC": {
#                 "exmae": 1.63171940688585
#             }
#         }
#     },
#     "TAPOCO, NC": {
#         "keymae": 0.980067356613127,
#         "exogen": {
#             "GATLINBURG 2 SW, TN|NEWFOUND GAP, TN|TOWNSEND 5S, TN": {
#                 "exmae": 1.57645602959139
#             },
#             "GATLINBURG 2 SW, TN": {
#                 "exmae": 1.49721633353601
#             },
#             "NEWFOUND GAP, TN": {
#                 "exmae": 1.55014567375166
#             },
#             "TOWNSEND 5S, TN": {
#                 "exmae": 2.14021919329974
#             },
#             "GATLINBURG 2 SW, TN|NEWFOUND GAP, TN": {
#                 "exmae": 1.54893980808917
#             },
#             "GATLINBURG 2 SW, TN|TOWNSEND 5S, TN": {
#                 "exmae": 1.61667169050498
#             },
#             "NEWFOUND GAP, TN|TOWNSEND 5S, TN": {
#                 "exmae": 2.43697193345116
#             }
#         }
#     },
#     "TRYON, NC": {
#         "keymae": 2.6823507498407,
#         "exogen": {
#             "GREENVILLE-SPARTANBURG AREA, SC|CAESARS HEAD, SC|CHESNEE 7 WSW, SC|CLEVELAND 3S, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 3.73113441570112
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC": {
#                 "exmae": 2.98693181001316
#             },
#             "CAESARS HEAD, SC": {
#                 "exmae": 3.10728725242017
#             },
#             "CHESNEE 7 WSW, SC": {
#                 "exmae": 2.81591118269417
#             },
#             "CLEVELAND 3S, SC": {
#                 "exmae": 3.07744617679545
#             },
#             "SPARTANBURG 3 SSE, SC": {
#                 "exmae": 2.81264900196712
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CAESARS HEAD, SC": {
#                 "exmae": 2.94254975336808
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CHESNEE 7 WSW, SC": {
#                 "exmae": 2.8608751566191
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CLEVELAND 3S, SC": {
#                 "exmae": 3.04963225908892
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 2.91447760992027
#             },
#             "CAESARS HEAD, SC|CHESNEE 7 WSW, SC": {
#                 "exmae": 2.97628635780226
#             },
#             "CAESARS HEAD, SC|CLEVELAND 3S, SC": {
#                 "exmae": 3.20189310778487
#             },
#             "CAESARS HEAD, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 3.09681922889283
#             },
#             "CHESNEE 7 WSW, SC|CLEVELAND 3S, SC": {
#                 "exmae": 2.99034586569205
#             },
#             "CHESNEE 7 WSW, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 2.89048685148226
#             },
#             "CLEVELAND 3S, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 3.04360857457204
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CAESARS HEAD, SC|CHESNEE 7 WSW, SC": {
#                 "exmae": 2.9033859279655
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CAESARS HEAD, SC|CLEVELAND 3S, SC": {
#                 "exmae": 3.15452544152697
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CAESARS HEAD, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 2.93147476679628
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CHESNEE 7 WSW, SC|CLEVELAND 3S, SC": {
#                 "exmae": 2.97134865473818
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CHESNEE 7 WSW, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 2.86854756656046
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CLEVELAND 3S, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 3.01618903938754
#             },
#             "CAESARS HEAD, SC|CHESNEE 7 WSW, SC|CLEVELAND 3S, SC": {
#                 "exmae": 2.99567340879987
#             },
#             "CAESARS HEAD, SC|CHESNEE 7 WSW, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 2.93705720085925
#             },
#             "CAESARS HEAD, SC|CLEVELAND 3S, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 3.27773721400751
#             },
#             "CHESNEE 7 WSW, SC|CLEVELAND 3S, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 2.96672263235551
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CAESARS HEAD, SC|CHESNEE 7 WSW, SC|CLEVELAND 3S, SC": {
#                 "exmae": 3.19041626801688
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CAESARS HEAD, SC|CHESNEE 7 WSW, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 2.87719587712741
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CAESARS HEAD, SC|CLEVELAND 3S, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 3.02929991921639
#             },
#             "GREENVILLE-SPARTANBURG AREA, SC|CHESNEE 7 WSW, SC|CLEVELAND 3S, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 2.97516787627304
#             },
#             "CAESARS HEAD, SC|CHESNEE 7 WSW, SC|CLEVELAND 3S, SC|SPARTANBURG 3 SSE, SC": {
#                 "exmae": 3.25873883598366
#             }
#         }
#     },
#     "WAYNESVILLE 1 E, NC": {
#         "keymae": 1.74748213942306,
#         "exogen": {
#             "MT LECONTE, TN|NEWFOUND GAP, TN": {
#                 "exmae": 2.23399934555202
#             },
#             "MT LECONTE, TN": {
#                 "exmae": 2.06704738290145
#             },
#             "NEWFOUND GAP, TN": {
#                 "exmae": 2.26207643894064
#             }
#         }
#     }
# }

# %% [markdown]
# Now that all the data is pulled out of a DataFrame and now in an equivalent Dictionary object.  Merge with AllMAE.json file

# %%
all_results_filename = os.path.join(destdir, 'allMAE.json')

# %%
all_results_filename = os.path.join(destdir, 'allMAE.json')
with open(all_results_filename, "r") as all_results_file:
    all_results = json.loads(all_results_file.read())

target_location_list = list(almostcomplete_dict.keys())

for i in range(0, len(target_location_list)):
    key = target_location_list[i]
    if key not in all_results:
        raise TypeError("Target Location Not Found ({0})".format(key))
    
    if all_results[key]['keymae'] is not None:
        if round(all_results[key]['keymae'],9) != round(almostcomplete_dict[key]['keymae'],9):
            print("MISMATCH ERROR: (all_results[{0}]['keymae'] = {1}) != {2}".format(key, all_results[key]['keymae'], almostcomplete_dict[key]['keymae']))
    else:
        all_results[key]['keymae'] = round(almostcomplete_dict[key]['keymae'],9)
    
    exog_list = list(almostcomplete_dict[key]['exogen'].keys())
    for j in range(0, len(exog_list)):
        exog_key = exog_list[j]
        if exog_key not in all_results[key]['exogen']:
            print("ExogLocation in {0} Not Found ({1})".format(key, exog_key))
            continue
        
        if all_results[key]['exogen'][exog_key]['exmae'] is not None:
            if round(all_results[key]['exogen'][exog_key]['exmae'], 9) != round(almostcomplete_dict[key]['exogen'][exog_key]['exmae'], 9):
                print("MISMATCH ERROR: (all_results[{0}]['exogen'][{1}]['exmae'] = {2}) != {3}".format(
                    key,
                    exog_key,
                    all_results[key]['exogen'][exog_key]['exmae'],
                    almostcomplete_dict[key]['exogen'][exog_key]['exmae']
                ))
            else:  # simplify all answers to 9 digits
                all_results[key]['exogen'][exog_key]['exmae'] = round(all_results[key]['exogen'][exog_key]['exmae'],9)
        else:
            all_results[key]['exogen'][exog_key]['exmae'] = round(almostcomplete_dict[key]['exogen'][exog_key]['exmae'], 9)
        

# print(json.dumps(all_results, indent=4, sort_keys=True))
# with open(all_results_filename, "w") as all_results_file:
#     all_results_file.write( json.dumps(all_results, indent=4, sort_keys=True)+'\n' )
#     print("Exported to File: {0}".format(all_results_filename))
# Out:
# MISMATCH ERROR: (all_results[ARCOLA, NC]['keymae'] = 1.5479680814163455) != 1.54425586234438
# MISMATCH ERROR: (all_results[GRANDFATHER MTN, NC]['keymae'] = 2.583667713) != 2.58806403787115
# MISMATCH ERROR: (all_results[GRANDFATHER MTN, NC]['exogen'][ELIZABETHTON, TN|ROAN MOUNTAIN 3SW, TN]['exmae'] = 2.797569592) != 2.97106152453339
# MISMATCH ERROR: (all_results[GRANDFATHER MTN, NC]['exogen'][ELIZABETHTON, TN]['exmae'] = 2.544987837) != 2.69524767468778
# MISMATCH ERROR: (all_results[GRANDFATHER MTN, NC]['exogen'][ROAN MOUNTAIN 3SW, TN]['exmae'] = 2.799639392) != 2.97845074957975
# Exported to File: /Users/gbpackers225/Development/lilfetz22/CapstoneProject1/data/manipulated_data/allMAE.json

# %% [markdown]
# ### Now remove leftover placeholders that still exist in preparation for recalculation

# %%
with open(all_results_filename, "r") as all_results_file:
    all_results = json.loads(all_results_file.read())

targetlocs = list(all_results.keys())
for i in range(0, len(targetlocs)):
    key = targetlocs[i]
    
    if all_results[key]['keymae'] is None:
        all_results[key].pop('data_source_sha1')
        print("MISSING KEYMAE: all_results[{0}]['keymae'] = {1}".format(key, all_results[key]['keymae']))
        
    elif key in almostcomplete_dict:
        if round(all_results[key]['keymae'],9) != round(almostcomplete_dict[key]['keymae'],9):
            print("SOLVING MISMATCH ERROR (reset): all_results[{0}]['keymae'] = None".format(key))
            all_results[key]['keymae'] = None
            all_results[key].pop('data_source_sha1')
    
    exog_list = list(all_results[key]['exogen'].keys())
    for j in range(0, len(exog_list)):
        exog_key = exog_list[j]
        
        if all_results[key]['exogen'][exog_key]['exmae'] is None:
            all_results[key]['exogen'].pop(exog_key)
            print("MISSING EXMAE: all_results[{0}]['exogen'][{1}]".format(key, exog_key))
            
        elif key in almostcomplete_dict and exog_key in almostcomplete_dict[key]['exogen']:
            if round(all_results[key]['exogen'][exog_key]['exmae'], 9) != round(almostcomplete_dict[key]['exogen'][exog_key]['exmae'], 9):
                print("SOLVING MISMATCH ERROR (reset): all_results[{0}]['exogen'][{1}]['exmae'] = None".format(key, exog_key))
                all_results[key]['exogen'][exog_key]['exmae'] = None
                all_results[key]['exogen'][exog_key].pop('data_source_sha1')
            
# print(json.dumps(all_results, indent=4, sort_keys=True))
with open(all_results_filename, "w") as all_results_file:
    all_results_file.write( json.dumps(all_results, indent=4, sort_keys=True)+'\n' )
    print("Exported to File: {0}".format(all_results_filename))
# Out:
# SOLVING MISMATCH ERROR (reset): all_results[ARCOLA, NC]['keymae'] = None
# MISSING EXMAE: all_results[BURLINGTON, NC]['exogen'][CHATHAM, VA]
# MISSING EXMAE: all_results[BURLINGTON, NC]['exogen'][CHATHAM, VA|MARTINSVILLE FILTER PLANT, VA]
# MISSING EXMAE: all_results[BURLINGTON, NC]['exogen'][CHATHAM, VA|MARTINSVILLE FILTER PLANT, VA|SOUTH BOSTON, VA]
# MISSING EXMAE: all_results[BURLINGTON, NC]['exogen'][CHATHAM, VA|SOUTH BOSTON, VA]
# MISSING EXMAE: all_results[BURLINGTON, NC]['exogen'][MARTINSVILLE FILTER PLANT, VA|SOUTH BOSTON, VA]
# MISSING EXMAE: all_results[BURLINGTON, NC]['exogen'][SOUTH BOSTON, VA]
# SOLVING MISMATCH ERROR (reset): all_results[GRANDFATHER MTN, NC]['keymae'] = None
# SOLVING MISMATCH ERROR (reset): all_results[GRANDFATHER MTN, NC]['exogen'][ELIZABETHTON, TN]['exmae'] = None
# SOLVING MISMATCH ERROR (reset): all_results[GRANDFATHER MTN, NC]['exogen'][ELIZABETHTON, TN|ROAN MOUNTAIN 3SW, TN]['exmae'] = None
# SOLVING MISMATCH ERROR (reset): all_results[GRANDFATHER MTN, NC]['exogen'][ROAN MOUNTAIN 3SW, TN]['exmae'] = None
# MISSING EXMAE: all_results[GREENSBORO AP, NC]['exogen'][MARTINSVILLE FILTER PLANT, VA|MEADOWS OF DAN 5 SW, VA]
# MISSING EXMAE: all_results[GREENSBORO AP, NC]['exogen'][MARTINSVILLE FILTER PLANT, VA|MEADOWS OF DAN 5 SW, VA|STUART, VA]
# MISSING EXMAE: all_results[GREENSBORO AP, NC]['exogen'][MEADOWS OF DAN 5 SW, VA]
# MISSING EXMAE: all_results[GREENSBORO AP, NC]['exogen'][MEADOWS OF DAN 5 SW, VA|STUART, VA]
# MISSING EXMAE: all_results[JACKSON SPRINGS 5 WNW, NC]['exogen'][CHERAW, SC|PAGELAND 9.0 WNW, SC]
# MISSING EXMAE: all_results[JACKSON SPRINGS 5 WNW, NC]['exogen'][CHESTERFIELD 3 E, SC|CHERAW, SC|PAGELAND 9.0 WNW, SC]
# MISSING EXMAE: all_results[JACKSON SPRINGS 5 WNW, NC]['exogen'][CHESTERFIELD 3 E, SC|PAGELAND 9.0 WNW, SC]
# MISSING EXMAE: all_results[JACKSON SPRINGS 5 WNW, NC]['exogen'][PAGELAND 9.0 WNW, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][CAESARS HEAD, SC|CLEVELAND 3S, SC|LONG CREEK, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][CAESARS HEAD, SC|CLEVELAND 3S, SC|LONG CREEK, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][CAESARS HEAD, SC|CLEVELAND 3S, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][CAESARS HEAD, SC|LONG CREEK, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][CLEVELAND 3S, SC|LONG CREEK, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][LONG CREEK, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC|CLEVELAND 3S, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC|CLEVELAND 3S, SC|LONG CREEK, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC|CLEVELAND 3S, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC|LONG CREEK, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC|LONG CREEK, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][PICKENS AREA, SC|CLEVELAND 3S, SC|LONG CREEK, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][PICKENS AREA, SC|CLEVELAND 3S, SC|LONG CREEK, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][PICKENS AREA, SC|CLEVELAND 3S, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAKE TOXAWAY 2 SW, NC]['exogen'][PICKENS AREA, SC|LONG CREEK, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DARLINGTON, SC|DILLON, SC|CHESTERFIELD 3 E, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DARLINGTON, SC|DILLON, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|CHESTERFIELD 3 E, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DARLINGTON, SC|DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DARLINGTON, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DARLINGTON, SC|FLORENCE REGIONAL AIRPORT, SC|CHESTERFIELD 3 E, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DARLINGTON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DARLINGTON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DARLINGTON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DILLON, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|CHESTERFIELD 3 E, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][DILLON, SC|FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC|CHERAW, SC]
# MISSING EXMAE: all_results[LAURINBURG, NC]['exogen'][FLORENCE REGIONAL AIRPORT, SC|FLORENCE 8 NE, SC|CHESTERFIELD 3 E, SC|CHERAW, SC]
# MISSING EXMAE: all_results[MARSHALL, NC]['exogen'][ERWIN 1 W, TN|GREENEVILLE EXP STA, TN]
# MISSING EXMAE: all_results[MARSHALL, NC]['exogen'][ERWIN 1 W, TN|NEWPORT 1 NW, TN]
# MISSING EXMAE: all_results[MARSHALL, NC]['exogen'][GREENEVILLE EXP STA, TN|NEWPORT 1 NW, TN]
# MISSING EXMAE: all_results[MARSHALL, NC]['exogen'][NEWPORT 1 NW, TN]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|GAFFNEY 6 E, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESNEE 7 WSW, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESNEE 7 WSW, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESNEE 7 WSW, SC|FORT MILL 4 NW, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESNEE 7 WSW, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|CHESTER 1 SE, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|FORT MILL 4 NW, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CATAWBA, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|FORT MILL 4 NW, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|GAFFNEY 6 E, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|CHESTER 1 SE, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|FORT MILL 4 NW, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESNEE 7 WSW, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESTER 1 SE, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESTER 1 SE, SC|FORT MILL 4 NW, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESTER 1 SE, SC|FORT MILL 4 NW, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][CHESTER 1 SE, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING EXMAE: all_results[MOUNT HOLLY 4 NE, NC]['exogen'][FORT MILL 4 NW, SC|GAFFNEY 6 E, SC|LOCKHART, SC]
# MISSING KEYMAE: all_results[OCONALUFTEE, NC]['keymae'] = None
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][GATLINBURG 2 SW, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][GATLINBURG 2 SW, TN|MT LECONTE, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][GATLINBURG 2 SW, TN|MT LECONTE, TN|NEWFOUND GAP, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][GATLINBURG 2 SW, TN|MT LECONTE, TN|NEWFOUND GAP, TN|TOWNSEND 5S, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][GATLINBURG 2 SW, TN|MT LECONTE, TN|TOWNSEND 5S, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][GATLINBURG 2 SW, TN|NEWFOUND GAP, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][GATLINBURG 2 SW, TN|NEWFOUND GAP, TN|TOWNSEND 5S, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][GATLINBURG 2 SW, TN|TOWNSEND 5S, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][MT LECONTE, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][MT LECONTE, TN|NEWFOUND GAP, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][MT LECONTE, TN|NEWFOUND GAP, TN|TOWNSEND 5S, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][MT LECONTE, TN|TOWNSEND 5S, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][NEWFOUND GAP, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][NEWFOUND GAP, TN|TOWNSEND 5S, TN]
# MISSING EXMAE: all_results[OCONALUFTEE, NC]['exogen'][TOWNSEND 5S, TN]
# MISSING KEYMAE: all_results[PISGAH FOREST 3 NE, NC]['keymae'] = None
# MISSING EXMAE: all_results[PISGAH FOREST 3 NE, NC]['exogen'][CAESARS HEAD, SC]
# MISSING EXMAE: all_results[PISGAH FOREST 3 NE, NC]['exogen'][CAESARS HEAD, SC|CLEVELAND 3S, SC]
# MISSING EXMAE: all_results[PISGAH FOREST 3 NE, NC]['exogen'][CLEVELAND 3S, SC]
# MISSING EXMAE: all_results[PISGAH FOREST 3 NE, NC]['exogen'][PICKENS AREA, SC]
# MISSING EXMAE: all_results[PISGAH FOREST 3 NE, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC]
# MISSING EXMAE: all_results[PISGAH FOREST 3 NE, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC|CLEVELAND 3S, SC]
# MISSING EXMAE: all_results[PISGAH FOREST 3 NE, NC]['exogen'][PICKENS AREA, SC|CLEVELAND 3S, SC]
# MISSING KEYMAE: all_results[ROBBINSVILLE AG 5 NE, NC]['keymae'] = None
# MISSING EXMAE: all_results[ROBBINSVILLE AG 5 NE, NC]['exogen'][MT LECONTE, TN]
# MISSING EXMAE: all_results[ROBBINSVILLE AG 5 NE, NC]['exogen'][MT LECONTE, TN|NEWFOUND GAP, TN]
# MISSING EXMAE: all_results[ROBBINSVILLE AG 5 NE, NC]['exogen'][MT LECONTE, TN|NEWFOUND GAP, TN|TOWNSEND 5S, TN]
# MISSING EXMAE: all_results[ROBBINSVILLE AG 5 NE, NC]['exogen'][MT LECONTE, TN|TOWNSEND 5S, TN]
# MISSING EXMAE: all_results[ROBBINSVILLE AG 5 NE, NC]['exogen'][NEWFOUND GAP, TN]
# MISSING EXMAE: all_results[ROBBINSVILLE AG 5 NE, NC]['exogen'][NEWFOUND GAP, TN|TOWNSEND 5S, TN]
# MISSING EXMAE: all_results[ROBBINSVILLE AG 5 NE, NC]['exogen'][TOWNSEND 5S, TN]
# MISSING KEYMAE: all_results[ROSMAN, NC]['keymae'] = None
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][CAESARS HEAD, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][CAESARS HEAD, SC|CLEVELAND 3S, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][CAESARS HEAD, SC|CLEVELAND 3S, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][CAESARS HEAD, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][CLEVELAND 3S, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][CLEVELAND 3S, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][PICKENS AREA, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC|CLEVELAND 3S, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC|CLEVELAND 3S, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][PICKENS AREA, SC|CAESARS HEAD, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][PICKENS AREA, SC|CLEVELAND 3S, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][PICKENS AREA, SC|CLEVELAND 3S, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][PICKENS AREA, SC|WALHALLA, SC]
# MISSING EXMAE: all_results[ROSMAN, NC]['exogen'][WALHALLA, SC]
# MISSING KEYMAE: all_results[SHELBY 2 NW, NC]['keymae'] = None
# MISSING EXMAE: all_results[SHELBY 2 NW, NC]['exogen'][CHESNEE 7 WSW, SC]
# MISSING EXMAE: all_results[SHELBY 2 NW, NC]['exogen'][CHESNEE 7 WSW, SC|GAFFNEY 6 E, SC]
# MISSING EXMAE: all_results[SHELBY 2 NW, NC]['exogen'][GAFFNEY 6 E, SC]
# Exported to File: /Users/gbpackers225/Development/lilfetz22/CapstoneProject1/data/manipulated_data/allMAE.json

# %%
# adjusting values down to 9 digits

with open(all_results_filename, "r") as all_results_file:
    all_results = json.loads(all_results_file.read())

targetlocs = list(all_results.keys())
for i in range(0, len(targetlocs)):
    key = targetlocs[i]
    
    if all_results[key]['keymae'] is not None:
        current_keymae = all_results[key]['keymae']
        if round(current_keymae, 9) != current_keymae:             # it is not rounded
            all_results[key]['keymae'] = round(current_keymae, 9)
            print("Adjusted keymae value: (orig[{0}] = {1}) => {2}".format(key, current_keymae, all_results[key]['keymae']))
            
    if 'exogen' in all_results[key]:
        exog_list = list(all_results[key]['exogen'].keys())
        for j in range(0, len(exog_list)):
            exog_key = exog_list[j]
        
            if all_results[key]['exogen'][exog_key]['exmae'] is not None:
                current_exmae = all_results[key]['exogen'][exog_key]['exmae']
                if round(current_exmae, 9) != current_exmae:             # it is not rounded
                    all_results[key]['exogen'][exog_key]['exmae'] = round(current_exmae, 9)
                    print("Adjusted exmae value: (orig[{0}][{1}] = {2}) => {3}".format(key, exog_key, current_exmae, all_results[key]['exogen'][exog_key]['exmae']))
            
# print(json.dumps(all_results, indent=4, sort_keys=True))
# with open(all_results_filename, "w") as all_results_file:
#     all_results_file.write( json.dumps(all_results, indent=4, sort_keys=True)+'\n' )
#     print("Exported to File: {0}".format(all_results_filename))
# Out:
# Adjusted keymae value: (orig[BOONE 1 SE, NC] = 2.4809657084670653) => 2.480965708
# Adjusted exmae value: (orig[BOONE 1 SE, NC][ROAN MOUNTAIN 3SW, TN] = 3.1150406350016864) => 3.115040635
# Adjusted keymae value: (orig[CASAR, NC] = 1.9931330930000002) => 1.993133093
# Adjusted keymae value: (orig[DANBURY, NC] = 1.5765827847357705) => 1.576582785
# Adjusted exmae value: (orig[DANBURY, NC][MARTINSVILLE FILTER PLANT, VA] = 1.8526283068064833) => 1.852628307
# Adjusted exmae value: (orig[DANBURY, NC][MARTINSVILLE FILTER PLANT, VA|MEADOWS OF DAN 5 SW, VA] = 2.082558684944888) => 2.082558685
# Adjusted exmae value: (orig[DANBURY, NC][MARTINSVILLE FILTER PLANT, VA|MEADOWS OF DAN 5 SW, VA|STUART, VA] = 2.021224928021283) => 2.021224928
# Adjusted exmae value: (orig[DANBURY, NC][MARTINSVILLE FILTER PLANT, VA|STUART, VA] = 2.043754322484901) => 2.043754322
# Adjusted exmae value: (orig[DANBURY, NC][MEADOWS OF DAN 5 SW, VA] = 1.913366953756763) => 1.913366954
# Adjusted exmae value: (orig[DANBURY, NC][MEADOWS OF DAN 5 SW, VA|STUART, VA] = 1.9742144456689674) => 1.974214446
# Adjusted exmae value: (orig[DANBURY, NC][STUART, VA] = 1.92662463835457) => 1.926624638
# Adjusted keymae value: (orig[EDEN, NC] = 1.5210608625653732) => 1.521060863
# Adjusted exmae value: (orig[EDEN, NC][CHATHAM, VA] = 1.8460850166486298) => 1.846085017
# Adjusted exmae value: (orig[EDEN, NC][CHATHAM, VA|MARTINSVILLE FILTER PLANT, VA] = 1.9828068829644228) => 1.982806883
# Adjusted exmae value: (orig[EDEN, NC][CHATHAM, VA|MARTINSVILLE FILTER PLANT, VA|STUART, VA] = 1.9703034738851732) => 1.970303474
# Adjusted exmae value: (orig[EDEN, NC][CHATHAM, VA|STUART, VA] = 1.982617107695725) => 1.982617108
# Adjusted exmae value: (orig[EDEN, NC][MARTINSVILLE FILTER PLANT, VA] = 2.100087194837946) => 2.100087195
# Adjusted exmae value: (orig[EDEN, NC][MARTINSVILLE FILTER PLANT, VA|STUART, VA] = 2.0707214833972962) => 2.070721483
# Adjusted exmae value: (orig[EDEN, NC][STUART, VA] = 1.8660122347425452) => 1.866012235
# Adjusted keymae value: (orig[HAYESVILLE 1 NE, NC] = 1.6711909172121096) => 1.671190917
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][BLAIRSVILLE EXP STA, GA] = 1.963876095477006) => 1.963876095
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][BLAIRSVILLE EXP STA, GA|HELEN, GA] = 2.112759535717524) => 2.112759536
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][BLAIRSVILLE EXP STA, GA|HELEN, GA|SAUTEE 3W, GA] = 2.2184897495919413) => 2.21848975
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][BLAIRSVILLE EXP STA, GA|SAUTEE 3W, GA] = 2.1983237884410327) => 2.198323788
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][CLAYTON 1 SSW, GA] = 1.927083149390412) => 1.927083149
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][CLAYTON 1 SSW, GA|BLAIRSVILLE EXP STA, GA] = 1.9887392505158472) => 1.988739251
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][CLAYTON 1 SSW, GA|BLAIRSVILLE EXP STA, GA|HELEN, GA] = 2.0750937861552172) => 2.075093786
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][CLAYTON 1 SSW, GA|BLAIRSVILLE EXP STA, GA|HELEN, GA|SAUTEE 3W, GA] = 2.1716228662839745) => 2.171622866
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][CLAYTON 1 SSW, GA|BLAIRSVILLE EXP STA, GA|SAUTEE 3W, GA] = 2.175204145106459) => 2.175204145
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][CLAYTON 1 SSW, GA|HELEN, GA] = 2.067363942502022) => 2.067363943
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][CLAYTON 1 SSW, GA|HELEN, GA|SAUTEE 3W, GA] = 2.2498543360985828) => 2.249854336
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][CLAYTON 1 SSW, GA|SAUTEE 3W, GA] = 2.2310358276039453) => 2.231035828
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][HELEN, GA] = 2.117885806178534) => 2.117885806
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][HELEN, GA|SAUTEE 3W, GA] = 2.324997605865302) => 2.324997606
# Adjusted exmae value: (orig[HAYESVILLE 1 NE, NC][SAUTEE 3W, GA] = 2.3463812670500572) => 2.346381267
# Adjusted keymae value: (orig[KING, NC] = 1.5797669943305384) => 1.579766994
# Adjusted exmae value: (orig[KING, NC][STUART, VA] = 1.838573506045001) => 1.838573506
# Adjusted keymae value: (orig[MARSHALL, NC] = 1.4291167444541135) => 1.429116744
# Adjusted exmae value: (orig[MARSHALL, NC][ERWIN 1 W, TN] = 1.639991509035022) => 1.639991509
# Adjusted exmae value: (orig[MARSHALL, NC][ERWIN 1 W, TN|GREENEVILLE EXP STA, TN|NEWPORT 1 NW, TN] = 1.6435891103593887) => 1.64358911
# Adjusted exmae value: (orig[MARSHALL, NC][GREENEVILLE EXP STA, TN] = 1.4447718434140582) => 1.444771843
# Adjusted keymae value: (orig[MONROE 2 SE, NC] = 1.7980278853798453) => 1.798027885
# Adjusted exmae value: (orig[MONROE 2 SE, NC][CATAWBA, SC] = 1.9310956942803539) => 1.931095694
# Adjusted exmae value: (orig[MONROE 2 SE, NC][CATAWBA, SC|FORT MILL 4 NW, SC] = 1.936799005728547) => 1.936799006
# Adjusted exmae value: (orig[MONROE 2 SE, NC][FORT MILL 4 NW, SC] = 1.8867418061943173) => 1.886741806
# Adjusted exmae value: (orig[MONROE 2 SE, NC][PAGELAND 9.0 WNW, SC] = 1.973851173779998) => 1.973851174
# Adjusted exmae value: (orig[MONROE 2 SE, NC][PAGELAND 9.0 WNW, SC|CATAWBA, SC] = 1.9806424994409355) => 1.980642499
# Adjusted exmae value: (orig[MONROE 2 SE, NC][PAGELAND 9.0 WNW, SC|CATAWBA, SC|FORT MILL 4 NW, SC] = 1.9824421301025994) => 1.98244213
# Adjusted exmae value: (orig[MONROE 2 SE, NC][PAGELAND 9.0 WNW, SC|FORT MILL 4 NW, SC] = 1.975315388650806) => 1.975315389
# Adjusted keymae value: (orig[MOUNT AIRY 2 W, NC] = 2.099951002610403) => 2.099951003
# Adjusted exmae value: (orig[MOUNT AIRY 2 W, NC][MEADOWS OF DAN 5 SW, VA] = 2.444849740845571) => 2.444849741
# Adjusted exmae value: (orig[MOUNT AIRY 2 W, NC][MEADOWS OF DAN 5 SW, VA|STUART, VA] = 2.578087305564499) => 2.578087306
# Adjusted exmae value: (orig[MOUNT AIRY 2 W, NC][STUART, VA] = 2.2994258836069448) => 2.299425884
# Adjusted keymae value: (orig[MOUNT HOLLY 4 NE, NC] = 1.6347849319999999) => 1.634784932
# Adjusted keymae value: (orig[MURPHY 4ESE, NC] = 1.6877677367159716) => 1.687767737
# Adjusted exmae value: (orig[MURPHY 4ESE, NC][BLAIRSVILLE EXP STA, GA] = 1.881828715446987) => 1.881828715
# Adjusted keymae value: (orig[REIDSVILLE 2 NW, NC] = 1.514675268256488) => 1.514675268
# Adjusted exmae value: (orig[REIDSVILLE 2 NW, NC][MARTINSVILLE FILTER PLANT, VA] = 1.98657992800681) => 1.986579928
# Exported to File: /Users/gbpackers225/Development/lilfetz22/CapstoneProject1/data/manipulated_data/allMAE.json
